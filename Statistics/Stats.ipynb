# %%
list1 = [171,
172,
171,
188,
160,
154,
122,
190,
152,
188]

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
#df = pd.read_csv('filename.csv')

# %%
df = pd.DataFrame(list1)

# %%
df
# Out:
#      0
# 0  171
# 1  172
# 2  171
# 3  188
# 4  160
# 5  154
# 6  122
# 7  190
# 8  152
# 9  188

# %%
df.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df.skew()
# Out:
# 0   -0.968063
# dtype: float64

# %%
df.kurt()
# Out:
# 0    1.139524
# dtype: float64

# %%
import math

# %%
df2 = df.apply(lambda a:math.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 df2 = df.apply(lambda a:log(a))
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:733, in FrameApply.apply(self)
#     730 elif self.raw:
#     731     return self.apply_raw()
# --> 733 return self.apply_standard()
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:857, in FrameApply.apply_standard(self)
#     856 def apply_standard(self):
# --> 857     results, res_index = self.apply_series_generator()
# ...

# %%
df2

# %%
df2.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.skew()
# Out:
# 0   -1.215544
# dtype: float64
